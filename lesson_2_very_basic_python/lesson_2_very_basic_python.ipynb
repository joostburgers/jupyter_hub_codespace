# %% [markdown]
# # Lesson 2 - Python Foundations
#
# **Overview**
#
# This lesson gives you the Python background you need to work with data in this course. The focus is on *using* code — loading data, calling functions, and reading what code does — rather than writing programs from scratch.
#
# **What you will learn:**
# 1. **Variables & Data Types** — how Python stores information and what goes wrong when types clash
# 2. **Calling Functions & Methods** — how to run code that others have written, including keyword arguments and dot notation
# 3. **Packages** — how to load tools like `pandas` with `import`
# 4. **Reading Code** — how to interpret `for` loops, `lambda`, and `try/except` when you see them

# %% [markdown]
# ### Anatomy of a Jupyter Cell
#
# Before we break each idea apart, look at a typical cell from a later lesson and see if you can spot the different pieces:
#
# ```python
# import pandas as pd                        # (1) import
#
# # Load the Reddit data file                # (2) comment
# df = pd.read_csv("data/jmu_reddit.csv")   # (3) variable  =  function call
#
# print(df.head())                           # (4) function call with a method
# ```
#
# Here is what each line is doing:
#
# | # | What you see | What it is |
# |---|---|---|
# | 1 | `import pandas as pd` | **Import** — loads a package and gives it a nickname |
# | 2 | `# Load the Reddit data file` | **Comment** — ignored by Python, explains the code for humans |
# | 3 | `df = pd.read_csv(...)` | **Variable** assigned the **return value** of a **function call** |
# | 4 | `print(df.head())` | **Function call** (`print`) wrapping a **method call** (`.head()`) |
#
# The rest of Part 2 explains each of these concepts in turn. By the end you will be able to read any cell like this without guessing.

# %% [markdown]
# ## Part 1: Selecting a Kernel
#
# Before you can run any code you have to select a "kernel". This is essentially a specific **version** of Python. This is because some packages rely on specific versions of Python. Luckily, Codespaces has taken care of most of this for us.
#
# 1. At the top right is the **Select Kernel** button.

# %% [markdown]
# ## Part 1: Variables & Data Types
#
# ### Computation and Variables
#
# Let's start with something simple: making the computer do math for us!
#
# **Think of Python like a very smart calculator** - you can tell it to add numbers, and it will give you the answer.
#
# **Tip**: Remember you can run the cell below in two ways:
#
# ✅ **Option 1:** Click the <img src="../lesson_assets/images/jupyter/run.svg" alt="Run" width="14"> Run button at the top left of the cell
# ✅ **Option 2:** <img src="../lesson_assets/images/windows.svg" alt="Windows" width="14"> `Ctrl+Enter` | <img src="../lesson_assets/images/apple.svg" alt="Mac" width="14"> `Shift+Enter`
#
# The answer will appear below the cell.

# %%
2+1
# Out:
# 3

# %% [markdown]
# ### What Are Variables?
#
# Adding specific numbers like `2 + 1` is fine, but the real magic happens when we use **variables**.
#
# **Think of a variable like a labeled box** where you can store information.
#
# In the example below:
# - We put the number `2` in a box labeled `x`
# - Then we can use `x` instead of writing `2` again
# - `x + 1` gives us the same result as `2 + 1`
#
# **Why is this useful?** You'll see in a moment! 🎯

# %%
x = 2
x + 1
# Out:
# 3

# %% [markdown]
# ### How Variables Work
#
# The `=` sign in Python means **"store this value"** - it's like putting something in a labeled box.
#
# ```python
# x = 2
# ```
#
# **Read this as:** "Store the number 2 in a box labeled x"
#
# ⚠️ **Important:** In Python, `=` does NOT mean "equals" like in math class. It means "store" or "assign."

# %% [markdown]
# ### Why Variables
#
# It may not be entirely obvious why you would want to store things in a variable. If you want to add `2` + `1`, storing `2` in the variable `x` seems like an extra step. The reason for doing so is that you do not always know what the information is going to be.
#
# **Example: Calculating a Reddit Post Score**
#
# In later lessons you will be working with Reddit data. Reddit calculates a post's **score** by subtracting downvotes from upvotes:
#
# ```
# score = upvotes - downvotes
# ```
#
# Without variables, you would hardcode every number directly — and repeat the formula each time:
#
# ```python
# 1204 - 37    # Post 1
# 892 - 15     # Post 2
# 3041 - 128   # Post 3
# ```
#
# With variables, you store the values once and the formula stays the same:
#
# ```python
# upvotes = 1204
# downvotes = 37
# score = upvotes - downvotes
# ```
#
# Now if the numbers change, you update one value — not the formula. When you get to processing thousands of Reddit posts, Python will swap in new values for `upvotes` and `downvotes` automatically for each one.

# %% [markdown]
# ### Data Types
#
# Python can store different **types** of information in variables. Here are the most important types:
#
# 1. **String** (`str`) — Text, always wrapped in quotes: `"Hello"`, `"James Madison University"`
# 2. **Integer** (`int`) — Whole numbers: `1`, `42`, `-5`
# 3. **List** — An ordered collection of values: `["JMU", "UVA", "Virginia Tech"]`
#
# Two additional types you will encounter:
# - **Float** (`float`) — Numbers with decimals: `3.14`, `2.0`
# - **Boolean** (`bool`) — True or False values, used in logic

# %% [markdown]
# Python automatically figures out what type of data you're storing. This makes Python easier to use than many other programming languages!

# %%
# Integer no decimal
a = 1

#float decimal
b = 2.0

#String quote marks
c = "Three"

#Bool reserved word True or False
d = True

# %% [markdown]
# **Want to check what type a variable is?** Use the `type()` function:

# %%
a = 1
type(a)
# Out:
# int

# %%
b = 2.0
type(b)
# Out:
# float

# %%
c = "Three"
type(c)
# Out:
# str

# %%
d = True
type(d)
# Out:
# bool

# %% [markdown]
# ### Common Errors 🚨
# The most common mistake beginners make is a `TypeError`. This happens when you try to mix incompatible data types.

# %% [markdown]
# ✅ **This works:** I can add `a` and `b` because they are both numbers.

# %%
# a = 1
# b = 2.0

a + b
# Out:
# 3.0

# %% [markdown]
# **Tip:** If you get the error below it is because a variable is not found. This is probably because you did not run the lines of code above. You can fix this by going back to the individual cells and executing them or clicking **Execute Above Cells**.
#
# ![Execute Above Cells](../lesson_assets/images/execute_above_cells.png)
#
# This will run all the code upstream.
#
# **1. NameError - Variable not defined:**
# ```python
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a + b
#
# NameError: name 'a' is not defined
# ```

# %% [markdown]
# ### TypeError
#
# ❌ **This won't work:** If I try to add `a` + `c` it will fail because they are different types.
#
# **Think of it like this:** 1 + "Three" doesn't make sense to a computer. It's like asking "What is 1 + Blue?"

# %% [markdown]
# ### Task 1:
# Create a new cell and add `a` + `c` and see what happens.
#
# **Creating a new cell**
#
# Click the <img src="../lesson_assets/images/jupyter/add.svg" alt="Add cell" width="14"> **+Code** button at the top of the toolbar.
# ![add code block](../lesson_assets/images/add_code_block.png)

# %%
#Create Code Here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Create Code Here
# ----> 2 a+c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# You should see an error that looks like this:
#
# ```python
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# ```
#
# **What does this mean?**
# - Python is saying: "I can't add an integer (whole number) and a string (text)"
# - This isn't a silly mistake! When working with real data, numbers sometimes get saved as text by accident
# - Always check your data types when you get strange errors
#
# **Why this matters:** Imagine you have a spreadsheet where some numbers are saved as text. Your calculations won't work until you fix the data types!

# %% [markdown]
# **Here's a tricky example:**
#
# Run the cell below and see what happens:

# %%
text1 = "Maroon"
text2 = "5"
text1 + text2
# Out:
# 'Maroon5'

# %% [markdown]
# **Surprise!** This actually works! ✅
#
# When you "add" two strings together, you get **string concatenation** (fancy word for "joining text together"). This does not work the other way though. Run the line below:

# %%
text1 = "Maroon"
text2 = "5"
text1 - text2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 text1 - text2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# We get the following error:
#
# ```python
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 text1 - text2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
# ```
#
# **What does this error mean in English?**
# - Python is telling us that the `-` (subtraction) operator doesn't work between two strings (`'str'` and `'str'`)
# - Unlike `+` which concatenates strings, there's no built-in way to "subtract" text
#
# **How to get help:**
# - Read the error message carefully - it tells you exactly what went wrong
# - The error type (`TypeError`) indicates a data type problem
# - Look at what types are involved (`'str' and 'str'`) and what operation failed (`-`)
# - When in doubt, drop the error in the chat, and AI will give you an explanation and possibly a solution in more readable language.

# %% [markdown]
# ### Numbers vs "Numbers"
# Sometimes numbers look like numbers, but they're actually text! Can you spot the problem below?

# %%
number1 = 567
number2 = "5309"
number1 + number2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 number1 = 567
#       2 number2 = "5309"
# ----> 3 number1 + number2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Problem Alert!**
#
# This gives us a TypeError because:
# - `567` is a number (integer)
# - `"5309"` is text (string) - notice the quotes!
#
# Even though "5309" looks like a number, the quotes make Python treat it as text. You can't do math with text!

# %% [markdown]
# ### Type Conversion
#
# **Good news!** You can convert between data types using built-in functions:
#
# - `int()` → Convert to whole number: `int("5309")` → `5309`
# - `float()` → Convert to decimal: `float("3.14")` → `3.14`
# - `str()` → Convert to text: `str(567)` → `"567"`
# - `bool()` → Convert to True/False
#
# **How to use:** Put your variable inside the parentheses: `int("5309")`

# %% [markdown]
# **Now our math works!** ✅ By converting the string to an integer with `int()`, we can add them:
#
# ```python
# number1 + int(number2)   # int() converts "5309" → 5309
# ```

# %%
number1 = 567
number2 = "5309"
number1 + int(number2)
# Out:
# 5876

# %% [markdown]
# ### Task 2: Type Conversion Practice
#
# What if you needed `number1` and `number2` side by side as text — like `"5675309"`?
#
# **Challenge:** Combine `number1` and `number2` into a single string using `str()` to convert `number1`.
#
# *Hint: converting `number1` to a string lets you use `+` for string concatenation.*

# %%
number1 = 567
number2 = "5309"
# Your code here
# Out:
# '5675309'

# %% [markdown]
# ### Summary
#
# - **Variables** — named containers that store a value for reuse
# - **Core types** — `int` (whole number), `float` (decimal), `str` (text), `bool` (True/False)
# - **TypeError** — occurs when an operation is performed on incompatible types (e.g. adding an integer and a string)
# - **Why it matters** — CSV files frequently store numbers as text by accident; recognizing and fixing type mismatches is one of the most common tasks in data science

# %% [markdown]
# ### Lists
#
# A **list** is a collection of data placed in a specific order. Lists are one of the most common data structures in data science — columns in a data table, rows of results, and search hits are all returned as lists. We will use advanced versions of lists in the upcoming lessons.
#
# You create a list using square brackets, with values separated by commas:
#
# ```python
# universities = ["JMU", "UVA", "Virginia Tech", "William and Mary"]
# ```
#
# Lists can hold any type of data: strings, numbers, or even a mix.

# %% [markdown]
# ### Accessing List Elements

# %% [markdown]
# You can access individual values in a list by using it's index. The index always starts at `0`, so the last index value for this list is `3` even though there are four items. We access this value by giving the name of the list and the index in brackets.

# %%
list1 = ["JMU", "UVA", "Virginia Tech", "William and Mary"]

# %% [markdown]
# What value will appear if I type `list1[2]`?

# %%
list1[2]
# Out:
# 'Virginia Tech'

# %% [markdown]
# You can also traverse lists from right to left by putting a `-` in front of the index. This means that `-1` is the last term in the list.

# %% [markdown]
# ### Task 3: Access List Items
#
# Using `list1`, write code to:
# 1. Access the **last item** using a negative index
# 2. Access **"UVA"** using its index number
#
# Remember: indexing starts at `0`.

# %%
list1 = ["JMU", "UVA", "Virginia Tech", "William and Mary"]
# Use list1 to complete the tasks below:

# 1. Access the last item using a negative index:

# 2. Access "UVA":

# %% [markdown]
# ### Summary
#
# - **List** — an ordered, one-dimensional collection of values accessed by position
# - **Index** — the position of an item, starting at `0`; use `list[0]` to get the first item
# - **Negative index** — counts from the end; `list[-1]` is always the last item
# - **Look ahead** — in Lesson 3 you will work with DataFrames, which are two-dimensional (rows and columns); understanding list indexing now makes that transition much easier

# %% [markdown]
# ## Part 2: Calling Functions & Methods
#
# Variables store data. **Functions and methods** are how you do things with that data. In these lessons you will mostly be *calling* functions that have already been written for you — not writing your own.

# %% [markdown]
# ### Calling Functions
#
# You have already been using **functions** — `type()`, `print()`, and `int()` are all functions. A function is a named operation: you give it input inside parentheses, and it produces output.
#
# ```python
# type(a)           # tells you the data type of a
# print("Hello")    # displays text
# int("5309")       # converts the string "5309" to the integer 5309
# ```
#
# Some functions take **keyword arguments** — named options that control exactly how the function runs. You will see this pattern constantly:
#
# ```python
# pd.read_csv("data.csv", encoding="utf-8")
# df.sample(n=5, random_state=42)
# ```
#
# The `n=5` and `encoding="utf-8"` parts are keyword arguments. The `name=value` pattern is all you need to recognize — the documentation for each function will always tell you what names are available.
#
# **A preview of Lesson 3:** In the next lesson you will use `plotly.express` to create interactive charts from Reddit data. The function call looks like this:
#
# ```python
# fig = px.bar(x=universities, y=scores, title="Reddit Scores by University")
# fig.show()
# ```
#
# Notice the pattern: keyword arguments (`x=`, `y=`, `title=`) control what the chart displays, and the result is stored in a variable (`fig`) so you can call the `.show()` method on it. Run the cell below to see it in action.

# %%
import plotly.express as px

universities = ["JMU", "UVA", "Virginia Tech", "William and Mary"]
scores = [1204, 892, 3041, 756]

fig = px.bar(x=universities, y=scores, title="YOUR TITLE HERE")
fig.show()

# %% [markdown]
# ### Task: Customize the Chart
#
# The chart below already runs — you just need to fill in two values. Everything else is already wired up.
#
# 1. Replace `"YOUR TITLE HERE"` with a title of your choice
# 2. Replace `"YOUR COLOR HERE"` with a color name (e.g. `"green"`) or a hex code (e.g. JMU purple: `"#450084"`)
#
# Notice that creating a chart is just a function call with keyword arguments — exactly the same pattern as `int()` or `print()`.

# %%
universities = ["JMU", "UVA", "Virginia Tech", "William and Mary"]
scores = [1204, 892, 3041, 756]

fig = px.bar(
    x=universities,
    y=scores,
    title="YOUR TITLE HERE",
    color_discrete_sequence=["#0000FF"]
)
fig.show()

# %% [markdown]
# ### Methods
#
# A **method** is a function that belongs to a specific data type and is accessed with dot notation. When you write `my_string.lower()`, you are asking the string to perform an operation on itself.
#
# The key pattern to recognize is:
#
# ```
# variable.method_name(arguments)
# ```
#
# In Lesson 3 you will start working with data tables (called DataFrames in pandas). Methods appear there too — they work the same way, just applied to columns instead of individual strings:
#
# ```python
# df['university'].str.lower()    # convert a whole column to lowercase
# df['score'].mean()              # calculate the average of a column
# ```

# %% [markdown]
# ### Task 4: Predict and Run
#
# String methods follow very consistent naming conventions. Look at the two examples in the code cell below — they run `.lower()` and `.upper()` on the same string.
#
# **Before running the cell:** predict what the third line — `name.title()` — will produce.
#
# Then run the cell to confirm.

# %%
name = "james madison university"

print(name.lower())   # → "james madison university"
print(name.upper())   # → "JAMES MADISON UNIVERSITY"
print(name.title())   # → ???
# Out:
# james madison university
# JAMES MADISON UNIVERSITY
# James Madison University

# %% [markdown]
# **Common string methods — keep this as a reference:**
#
# | Method | What it does | Example |
# |---|---|---|
# | `.lower()` | all lowercase | `"JMU".lower()` → `"jmu"` |
# | `.upper()` | ALL UPPERCASE | `"jmu".upper()` → `"JMU"` |
# | `.title()` | Title Case | `"james madison".title()` → `"James Madison"` |
# | `.strip()` | remove leading/trailing spaces | `"  JMU  ".strip()` → `"JMU"` |
# | `.replace("old", "new")` | swap text | `"JMU".replace("JMU", "Dukes")` → `"Dukes"` |
#
# Methods always use **dot notation**: the variable, a dot, the method name, and parentheses.

# %% [markdown]
# You can also **chain methods** — call one after another — in a single line:
#
# ```python
# messy_text = "  COLONIAL WILLIAMSBURG  "
# clean_text = messy_text.strip().title()
# # Result: "Colonial Williamsburg"
# ```
#
# This is common in data cleaning: `.strip()` removes extra spaces, then `.title()` capitalizes properly. You will see chains like this throughout these lessons.

# %% [markdown]
# ### Task 5: Chain Methods to Clean a Phone Number
#
# Real data is messy. Phone numbers in a dataset might look like any of these:
#
# ```
# "  (540) 568-6211  "
# "  (540) 568-6211  "
# ```
#
# **Challenge:** Using the variable `phone` below, write a single chained expression that:
# 1. Removes the leading and trailing spaces with `.strip()`
# 2. Removes the parentheses with `.replace("(", "").replace(")", "")`
# 3. Replaces the space and dash so the result is `"540-568-6211"`
#
# *Hint: each method returns a string, so you can immediately call the next method on it.*

# %%
phone = "  (540)568-6211  "

# Your chained expression here:
clean_phone = 
print(clean_phone)
# Out:
# 540-568-6211

# %% [markdown]
# ## Part 3: Packages
#
# In these lessons you will be working with libraries — collections of pre-built functions — rather than writing your own. Understanding how to load and use a package is one of the most practical Python skills you can have.

# %% [markdown]
# **What is a package?**
#
# A **package** is a collection of pre-written functions that other people have built and shared. Instead of writing every tool from scratch, you import a package and use the tools inside it.
#
# The `import` statement loads a package. The `as` keyword gives it a short nickname so you don't have to type the full name each time:
#
# ```python
# import pandas as pd       # data tables — nicknamed "pd"
# import nltk               # natural language processing
# import spacy              # location and entity extraction
# ```
#
# Packages are loaded once at the top of a notebook and then available everywhere below.

# %%
import pandas as pd

# %% [markdown]
# Once a package is imported, you access its functions using the prefix:
#
# ```python
# pd.read_csv("data.csv")       # load a CSV file
# pd.DataFrame(my_list)         # convert a list into a table
# ```
#
# You can also pass keyword arguments (the `name=value` pattern from Part 2) to customize how functions run:
#
# ```python
# df = pd.read_csv("data.csv", encoding="utf-8")
# df.head(10)
# ```
#
# You do not need to memorize which keyword arguments exist — the documentation (or a quick search) will always tell you what options are available for a given function.
#
# **Common mistake: forgetting to run the import cell**
#
# The most frequent error in these lessons is a `NameError` caused by skipping the `import` cell:
#
# ```python
# NameError: name 'pd' is not defined
# ```
#
# This means Python has never heard of `pd` — because the `import pandas as pd` cell was never run. The fix is always the same: scroll up, run the import cell, then re-run the cell that failed. When in doubt, use **Execute Above Cells** to make sure every cell above has been executed in order.
#
# ![Execute Above Cells](../lesson_assets/images/execute_above_cells.png)

# %% [markdown]
# ## Part 4: Reading Code
#
# As you work through these lessons you will encounter Python patterns that you do not need to write yourself, but that you do need to understand. This section gives you just enough background to read that code confidently.
#
# ### For Loops
#
# One of the most common features of any programming language is **iteration** — repeating the same operation for every item in a collection. In Python this is done with a `for` loop.
#
# A `for` loop has two parts:
# - A **header** that says what to loop over
# - An **indented body** that runs once for each item

# %% [markdown]
# The loop below goes through every university in a list and prints it in uppercase. **Read it as:** "For each `x` in `list4`, print `x` in uppercase."
#
# You will see this pattern throughout these lessons. You do not need to write `for` loops — just recognize what they are doing when you see them.

# %%
list4 = ["jmu", "uva", "virginia tech", "william and mary"]

for x in list4:
    print(x.upper())
# Out:
# JMU
# UVA
# VIRGINIA TECH
# WILLIAM AND MARY

# %% [markdown]
# ### Lambda
#
# A `lambda` is a compact, one-line function. You will see it most often with `.apply()`, which runs an operation on every row of a data column:
#
# ```python
# df['score'].apply(lambda x: x * 100)
# ```
#
# **How to read it:** "For each value `x` in the `score` column, multiply it by 100."
#
# Think of `lambda x:` as "a temporary variable called `x` that holds each item one at a time." You will not write lambdas in these lessons, but you will see them regularly.
#
# ```python
# # Another common example: classifying sentiment scores
# df['sentiment'].apply(lambda x: "positive" if x > 0 else "negative")
# ```

# %% [markdown]
# ### Try/Except
#
# A `try/except` block handles errors gracefully. Instead of crashing, Python tries one thing and falls back to another if it fails:
#
# ```python
# try:
#     result = int(value)
# except:
#     result = 0
# ```
#
# **How to read it:** "Try to convert `value` to an integer. If that causes an error, set `result` to `0` instead."
#
# This is common in data cleaning when some values in a column cannot be converted — rather than crashing the whole script, `try/except` lets the code handle bad data and keep running.

# %% [markdown]
# ## Lesson Summary
#
# You now have the Python foundation needed for data analysis. Here is what you covered:
#
# ### Part 1: Variables & Data Types
# - **Variables** — named containers that store information
# - **Core types** — `str` (text), `int` (whole number), `list` (ordered collection)
# - **`type()`** — check what type a variable is
# - **TypeError** — what it means and how to fix it with `int()`, `str()`, `float()`
#
# ### Part 2: Calling Functions & Methods
# - **Functions** — call them with `function_name(input)`
# - **Keyword arguments** — the `name=value` pattern: `read_csv("file.csv", encoding="utf-8")`
# - **Methods** — dot notation: `variable.method_name()`
# - **Chaining** — `text.strip().title()` runs methods one after another
#
# ### Part 3: Packages
# - **`import`** — loads a package: `import pandas as pd`
# - **Prefix notation** — `pd.read_csv()` means "use `read_csv` from pandas"
#
# ### Part 4: Reading Code
# - **For loops** — repeat an operation for each item: `for x in list: ...`
# - **Lambda** — compact one-line function: `lambda x: x * 100`
# - **Try/Except** — handle errors gracefully: try something, fall back if it fails
#
# ---
#
# These skills are the foundation for everything in the next lessons. You will be loading data, cleaning text, extracting locations, and analyzing sentiment — all by calling functions and methods from the packages that specialists have already built.
