# %% [markdown]
# 📋 **Instructions:**
#
# ## Assignment Overview
#
# In the first six lessons you learned how to:
#
# 1. **Scrape** Reddit data for a university subreddit
# 2. **Clean and wrangle** raw text data with pandas
# 3. **Extract locations** using Named Entity Recognition (NER)
# 4. **Geoparse** place names into real-world coordinates
# 5. **Run sentiment analysis** using RoBERTa
# 6. **Map emotions** spatially with Plotly
#
# Now you apply that full pipeline to **your assigned school** and compare the results to the data you created for JMU. Your goal is to produce:
#
# - A **cleaned, sentiment-annotated dataset** of both your assigned school and JMU
#   - You should already have a good version of the JMU data based on lessons 4–5. You can go back and keep editing the JMU file if you want to improve accuracy.
# - Maps that show *before* and *after* data cleaning
# - Two different maps of the same data that each tell a different story
# - A **written analysis** of what the maps reveal
# - Upon completion the content will populate the **`whitepaper.html`** page of your team website
#
# The format for this assignment is **fill in the blank**. You will go through and see four types of cells:
# 1. Headers — you do not need to touch these
# 2. Code cells — some will run automatically, others will require action on your part to make them work
# 3. Instruction cells — you do not need to touch these. They disappear when you publish the notebook
# 4. Content cells — these cells say `[ENTER TEXT HERE]`. You will replace that text with your own text.
#
# ---
#
# ## ⚠️ Before You Begin — Run the Data Pipeline First
#
# Before opening this notebook, you must run **[`project_part_1_data_pipeline.ipynb`](project_part_1_data_pipeline.ipynb)** to completion. That notebook:
#
# 1. Loads your team's Google Sheets location review
# 2. Applies corrections and exports `{SCHOOL}_geoparsed_long_cleaned.csv`
# 3. Runs RoBERTa sentiment and exports `{SCHOOL}_geoparsed_long_cleaned_sentiment.csv`
# 4. Commits and pushes the data files to GitHub via a pull request
#
# **This whitepaper notebook will not work correctly until those files exist.**
#
# Once the pipeline is complete, set your school name in the cell below and run it — all subsequent cells will use it automatically.

# %%
import os
import pandas as pd

SCHOOL = 'UNC'  # ← change to your school: GMU, ODU, UNC, UVA, VCU, VirginiaTech, WM

# ── Load sentiment data (produced by project_part_1_data_pipeline.ipynb) ──────────
_sentiment_path = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned_sentiment.csv'

if not os.path.exists(_sentiment_path):
    print(f'⛔ File not found: {_sentiment_path}')
    print('   Run project_part_1_data_pipeline.ipynb first, then re-run this cell.')
    df = None
else:
    df = pd.read_csv(_sentiment_path)
    print(f'✅ {SCHOOL}  |  {len(df):,} rows  |  {df["place"].nunique():,} unique places')
    print(f'   Columns: {list(df.columns)}')
# Out:
# ✅ UNC  |  1,263 rows  |  369 unique places
#    Columns: ['type', 'date', 'score', 'sentences', 'year_month', 'place', 'latitude', 'longitude', 'feature_type', 'admin1_name', 'admin2_name', 'country_name', 'school', 'place_type', 'roberta_neg', 'roberta_neu', 'roberta_pos', 'roberta_compound']

# %%
import sys, importlib
import pandas as pd
import plotly.express as px
import plotly.io as pio
import os

# Use notebook_connected renderer so Plotly figures are stored as HTML outputs
# in the saved .ipynb file — required for maps to appear in the published whitepaper.
pio.renderers.default = 'notebook_connected'

sys.path.insert(0, '..')
import tests.helpers as _helpers_mod
importlib.reload(_helpers_mod)
from tests.helpers import (aggregate_places, filter_places,
                           jenks_size_classify, jenks_count_classify, jenks_sentiment_classify)

print('✅ Map helpers loaded.')
# Out:
# ✅ Map helpers loaded.

# %% [markdown]
# 📋 **Instructions:**
# The title below is a generic one. Please change it to something catchier. This should be done last.

# %% [markdown]
# # Project Part 2: Analysis & Whitepaper [Change Title]

# %% [markdown]
# ## Introduction

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Write an introduction to the entire whitepaper.
# **Length:** 5-8 sentences
# **Detail:**
# This should be written last when you already know your results. It should include the following:
#
# - A description of both institutions and some of their most common characteristics.
#   - For example, you might focus on JMU being a residential school with a vibrant on-campus life while another school might be more known to be a commuter school.
# - An overview of the two datasets based on your reading of them. This should give some indication of what this data is about generally.
#   - For example, does one school appear to talk about football more versus another one?
# - A hypothesis about what different types of locations you expect to find for each school and how you would see this on the map.
# - An overview of the actual results making clear whether they affirmed or contradicted the hypothesis.
#   - For example, Given the high number of students from Northern Virginia, we hypothesized that there would be a closer connection to NoVa and regional affairs at JMU versus School X which only attracts students from the surrounding area.
# - Valuable insight gained from the maps.
#
# > 👉 **Note:** *You are essentially laying out your entire project in one paragraph.*

# %% [markdown]
# [ENTER INTRODUCTION TEXT HERE]

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# 📋 **Instructions:**
#
# Formulate a working theory (hypothesis) of how the two corpora differ or compare and explain how you might see that reflected in the data.
#
# **⚠️ Important Requirements:**
# - The hypothesis **must** be related to space and sentiment
# - Example of what **NOT** to do: "JMU students love math classes more than UNC students" (not spatial and cannot be answered by our data)
#
# #### 💡 Sample Hypotheses
#
# **Regional Scale Examples:**
# 1. UNC attracts more students from the southeast than JMU and therefore more positive sentiments will appear across South Carolina, Georgia, Alabama, and Florida.
#
# **Local Scale Examples:**
#
# 2. JMU has a very positive college atmosphere, and therefore sentiment around campus will appear more positive than that of UNC.
#
# Note that these hypotheses operate at two different spatial scales: regional and local.

# %% [markdown]
# [ENTER HYPOTHESIS TEXT HERE]

# %% [markdown]
# ## Corpus Description

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Give a global overview of both corpora.
# **Length:** 5-8 sentences
# **Detail:** Your overview should include a mix of quantitative and qualitative data. You should include the number of total posts and comments and how many years the thread has been active.
# Also provide more qualitative insights into what kinds of topics people appear to post about. You can do this by filtering the `_raw.csv` data file by posts. The goal is to give the reader a better sense of what the data is like.

# %% [markdown]
# [ENTER CORPUS DESCRIPTION TEXT HERE]

# %% [markdown]
# ## Corpus Analysis

# %% [markdown]
# ### Key Moments

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Provide a data driven analysis of key moments in the Reddit thread
# **Length:** 5-8 sentences
# **Detail:** The graph below shows a timeline of combined posts and comments for each school. Analyze the peaks for each school and see where posting overlaps and see where it diverges. Institutions might have a shared history around certain topics like Covid, but they may also diverge when it comes to topics like tuition or a big football victory. Your goal is to figure out the data under those "peaks" by going back and reading the raw csv file for those dates to get a better sense of what is going on. Then write up the shared and divergent key moments for each school.
#
# As chart similar to the one below was covered in lesson 3_2. You will have to designate a color for your own school. At the moment it is set to UNC light blue.

# %%
# ── Parameters to change ──────────────────────────────────────────────────
INTERVAL     = 'W'        # ← change to 'M' (monthly) or 'Y' (yearly)
SCHOOL_COLOR = '#4B9CD3'  # ← change to your school's color (current: UNC Carolina Blue)
JMU_COLOR    = '#450084'  # JMU purple — do not change

# ── Load both schools' raw data ───────────────────────────────────────────
_df_jmu    = pd.read_pickle('../data/JMU/JMU_raw.pickle')
_df_school = pd.read_pickle(f'../data/{SCHOOL}/{SCHOOL}_raw.pickle')

_df_jmu['school']    = 'JMU'
_df_school['school'] = SCHOOL

_df_combined = pd.concat([_df_jmu, _df_school], ignore_index=True)

# ── Group by interval and school, count all posts + comments ──────────────
_df_combined['interval'] = _df_combined['date'].dt.to_period(INTERVAL).dt.to_timestamp()
_interval_counts = _df_combined.groupby(['interval', 'school'], as_index=False).size()

# ── Plot ──────────────────────────────────────────────────────────────────
fig = px.line(
    _interval_counts,
    x='interval',
    y='size',
    color='school',
    color_discrete_map={'JMU': JMU_COLOR, SCHOOL: SCHOOL_COLOR},
    title=f'Posts and Comments Over Time: JMU vs {SCHOOL}',
    labels={'interval': 'Time Period', 'size': 'Number of Posts/Comments', 'school': 'School'},
    markers=True,
)
fig.update_layout(
    xaxis_title='Time Period',
    yaxis_title='Number of Posts/Comments',
    legend_title='School',
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="77350a84-c8fb-4a2a-a03a-e7986f8892b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("77350a84-c8fb-4a2a-a03a-e7986f8892b2")) {                    Plotly.newPlot(                        "77350a84-c8fb-4a2a-a03a-e7986f8892b2",                        [{"hovertemplate":"School=JMU\u003cbr\u003eTime Period=%{x}\u003cbr\u003eNumber of Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JMU","line":{"color":"#450084","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"JMU","orientation":"v","showlegend":true,"x":["2012-02-27T00:00:00.000000000","2012-04-16T00:00:00.000000000","2012-04-23T00:00:00.000000000","2012-05-21T00:00:00.000000000","2012-05-28T00:00:00.000000000","2012-06-04T00:00:00.000000000","2012-06-25T00:00:00.000000000","2012-10-29T00:00:00.000000000","2012-11-05T00:00:00.000000000","2012-11-12T00:00:00.000000000","2012-11-26T00:00:00.000000000","2013-04-22T00:00:00.000000000","2013-04-29T00:00:00.000000000","2013-10-21T00:00:00.000000000","2013-11-25T00:00:00.000000000","2014-02-24T00:00:00.000000000","2014-03-24T00:00:00.000000000","2014-04-14T00:00:00.000000000","2014-04-28T00:00:00.000000000","2014-05-19T00:00:00.000000000","2014-05-26T00:00:00.000000000","2014-06-23T00:00:00.000000000","2014-07-14T00:00:00.000000000","2015-03-23T00:00:00.000000000","2015-07-06T00:00:00.000000000","2015-07-13T00:00:00.000000000","2015-10-12T00:00:00.000000000","2015-10-19T00:00:00.000000000","2016-05-09T00:00:00.000000000","2017-01-02T00:00:00.000000000","2017-10-02T00:00:00.000000000","2017-10-23T00:00:00.000000000","2017-11-06T00:00:00.000000000","2017-11-13T00:00:00.000000000","2017-11-20T00:00:00.000000000","2017-12-04T00:00:00.000000000","2018-02-26T00:00:00.000000000","2018-08-13T00:00:00.000000000","2018-08-27T00:00:00.000000000","2018-09-10T00:00:00.000000000","2018-10-08T00:00:00.000000000","2018-10-22T00:00:00.000000000","2018-10-29T00:00:00.000000000","2018-11-12T00:00:00.000000000","2018-11-19T00:00:00.000000000","2018-11-26T00:00:00.000000000","2018-12-03T00:00:00.000000000","2018-12-10T00:00:00.000000000","2018-12-31T00:00:00.000000000","2019-01-07T00:00:00.000000000","2019-02-04T00:00:00.000000000","2019-02-18T00:00:00.000000000","2019-03-11T00:00:00.000000000","2019-03-25T00:00:00.000000000","2019-04-01T00:00:00.000000000","2019-04-08T00:00:00.000000000","2019-04-15T00:00:00.000000000","2019-04-22T00:00:00.000000000","2019-07-15T00:00:00.000000000","2019-08-12T00:00:00.000000000","2019-08-19T00:00:00.000000000","2019-08-26T00:00:00.000000000","2019-09-02T00:00:00.000000000","2019-09-09T00:00:00.000000000","2019-09-23T00:00:00.000000000","2019-10-07T00:00:00.000000000","2019-10-14T00:00:00.000000000","2019-10-28T00:00:00.000000000","2019-11-04T00:00:00.000000000","2019-11-11T00:00:00.000000000","2019-11-18T00:00:00.000000000","2019-11-25T00:00:00.000000000","2019-12-02T00:00:00.000000000","2019-12-09T00:00:00.000000000","2019-12-16T00:00:00.000000000","2019-12-23T00:00:00.000000000","2019-12-30T00:00:00.000000000","2020-01-06T00:00:00.000000000","2020-01-13T00:00:00.000000000","2020-01-20T00:00:00.000000000","2020-01-27T00:00:00.000000000","2020-02-03T00:00:00.000000000","2020-02-10T00:00:00.000000000","2020-02-17T00:00:00.000000000","2020-02-24T00:00:00.000000000","2020-03-02T00:00:00.000000000","2020-03-09T00:00:00.000000000","2020-03-16T00:00:00.000000000","2020-03-23T00:00:00.000000000","2020-03-30T00:00:00.000000000","2020-04-06T00:00:00.000000000","2020-04-13T00:00:00.000000000","2020-04-20T00:00:00.000000000","2020-04-27T00:00:00.000000000","2020-05-04T00:00:00.000000000","2020-05-11T00:00 ...

# %% [markdown]
# [ENTER KEY MOMENTS ANALYSIS HERE]

# %% [markdown]
# ### Key Topics

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Provide a data-driven analysis of the most discussed topics in each subreddit.
# **Length:** 5–8 sentences
# **Detail:** The chart below shows how frequently each keyword appears across posts and comments for both schools. Your first and most important task is to **decide which keywords are worth comparing**. A keyword like `class` will appear in almost every academic subreddit and tell you nothing interesting; a keyword like `tailgate` or `dining hall` may reveal something specific about campus culture at one school.
#
# To find good keywords:
# - Skim 20–30 posts from each school's `_raw.csv` file and note recurring topics, complaints, or celebrations
# - Think about what is *unique* to each school's context (athletics, geography, campus life, local events)
# - Avoid keywords so generic they appear everywhere (`good`, `people`, `year`) or so rare they barely register
#
# Once you have a chart you find meaningful, analyze it: which topics are **shared** across both schools, and which are **distinctive** to one? Do the differences reflect something meaningful about each institution?
#
# > 👉 **Note:** *Because the two corpora are different sizes, the chart uses counts per 1,000 posts so the schools are directly comparable.*

# %%
# ── Keywords to compare — change this list ───────────────────────────────
# Tip: skim each school's _raw.csv first to find topics that are actually
# discussed. Generic words ('good', 'people') or rare words produce flat bars.
KEYWORDS = ['tuition', 'covid', 'party', 'football', 'basketball', 'class', 'zoom', 'campus']

# ── Load raw data for both schools ────────────────────────────────────────
_df_jmu    = pd.read_pickle('../data/JMU/JMU_raw.pickle')
_df_school = pd.read_pickle(f'../data/{SCHOOL}/{SCHOOL}_raw.pickle')

# ── Count keyword mentions and normalize per 1,000 posts ─────────────────
# Normalizing makes the two corpora directly comparable even though they
# have different numbers of posts and comments.
_jmu_total    = len(_df_jmu)
_school_total = len(_df_school)

_rows = []
for kw in KEYWORDS:
    _jmu_hits    = _df_jmu['text'].str.contains(kw, case=False, na=False).sum()
    _school_hits = _df_school['text'].str.contains(kw, case=False, na=False).sum()
    _rows.append({'keyword': kw, 'school': 'JMU',    'per_1000': _jmu_hits    / _jmu_total    * 1000})
    _rows.append({'keyword': kw, 'school': SCHOOL,   'per_1000': _school_hits / _school_total * 1000})

_keyword_df = pd.DataFrame(_rows)

# ── Plot ──────────────────────────────────────────────────────────────────
fig = px.bar(
    _keyword_df,
    x='keyword',
    y='per_1000',
    color='school',
    barmode='group',
    color_discrete_map={'JMU': JMU_COLOR, SCHOOL: SCHOOL_COLOR},
    title=f'Keyword Frequency per 1,000 Posts: JMU vs {SCHOOL}',
    labels={'per_1000': 'Mentions per 1,000 Posts/Comments',
            'keyword': 'Keyword', 'school': 'School'},
)
fig.update_layout(
    xaxis_title='Keyword',
    yaxis_title='Mentions per 1,000 Posts/Comments',
    legend_title='School',
    xaxis={'categoryorder': 'total descending'},
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="9bb15566-c304-4715-a225-b2fe53d05ce6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9bb15566-c304-4715-a225-b2fe53d05ce6")) {                    Plotly.newPlot(                        "9bb15566-c304-4715-a225-b2fe53d05ce6",                        [{"alignmentgroup":"True","hovertemplate":"School=JMU\u003cbr\u003eKeyword=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JMU","marker":{"color":"#450084","pattern":{"shape":""}},"name":"JMU","offsetgroup":"JMU","orientation":"v","showlegend":true,"textposition":"auto","x":["tuition","covid","party","football","basketball","class","zoom","campus"],"xaxis":"x","y":{"dtype":"f8","bdata":"1OeD+cvYIUC\u002f20X2McU6QDSSIIvQMSpAqEj7H2+eKUB1xPM68JIDQL\u002fbRfYxxUpAdcTzOvCSA0BJJWthk1hLQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"School=UNC\u003cbr\u003eKeyword=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UNC","marker":{"color":"#4B9CD3","pattern":{"shape":""}},"name":"UNC","offsetgroup":"UNC","orientation":"v","showlegend":true,"textposition":"auto","x":["tuition","covid","party","football","basketball","class","zoom","campus"],"xaxis":"x","y":{"dtype":"f8","bdata":"tDJ72RrEE0CRRyWZW0c1QDOhSfkOQR5ATC+qcFOoDkAg3jcNgFgRQHxhsOy0WE1A\u002ftycP+j5FEDC2ENB+CRHQA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"soli ...

# %% [markdown]
# [ENTER KEY TOPICS ANALYSIS HERE]

# %% [markdown]
# ### Keyword Trends

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Identify up to three keywords that show the most meaningful difference — or the most surprising similarity — between the two schools and plot how their usage evolved over time.
# **Length:** 5–8 sentences
# **Detail:** Looking at your Key Topics bar chart, identify up to three keywords that have the highest analytical payoff: either a keyword one school uses far more than the other, or one that both schools spike around the same time (suggesting a shared event like COVID or a regional news story). You may use fewer than three if two keywords already tell a complete story — more lines can make the chart harder to read.
#
# To decide which keywords to keep:
# - A keyword is worth including if it produces at least one noticeable peak or divergence you can explain
# - If two keywords behave nearly identically, drop one — they are telling the same story
# - A flat line for both schools is not interesting unless the *absence* of a topic is itself meaningful
#
# **Adjusting the chart:** Two variables control how the chart looks:
# - `TREND_INTERVAL` — the time grouping. Finer intervals (`'W'` weekly, `'M'` monthly) show more detail but can produce spiky lines when post volume is low. Coarser intervals (`'Q'` quarterly, `'Y'` yearly) smooth the lines and reduce distortion because each bucket has more posts to normalize against. Start with `'Q'` and zoom in only if a quarterly chart already shows a clear story.
# - `MIN_PERIOD_POSTS` — any interval with fewer total posts than this threshold is dropped before normalization. Raise it to remove more noisy periods; lower it to keep them.
#
# **Color** distinguishes the two schools; **line pattern** (solid vs. dashed vs. dotted) distinguishes the keywords. Your written analysis should name each peak, explain what was happening at that time, and say what it reveals about each institution.

# %%
# ── Pick 1–3 keywords from your Key Topics chart ─────────────────────────
# Choose keywords that produced the most interesting peaks or divergences.
# You can use fewer than 3 if two keywords already tell a complete story.
TREND_KEYWORDS = ['covid', 'football', 'tuition']  # ← change these (1–3 keywords)

# ── Time interval for this chart ──────────────────────────────────────────
# Coarser intervals (Q, Y) pool more posts per bucket, which reduces
# normalization distortion and produces smoother lines.
# Options: 'W' (weekly), 'M' (monthly), 'Q' (quarterly), 'Y' (yearly)
TREND_INTERVAL = 'Y'  # ← change if needed (default: quarterly)

# ── Minimum posts per interval to include in the chart ───────────────────
# Intervals below this threshold are dropped before normalizing.
# Raise to suppress noisy periods; lower to include them.
MIN_PERIOD_POSTS = 10  # ← change if needed

# ── Load raw data for both schools ────────────────────────────────────────
_df_jmu    = pd.read_pickle('../data/JMU/JMU_raw.pickle')
_df_school = pd.read_pickle(f'../data/{SCHOOL}/{SCHOOL}_raw.pickle')

_df_jmu['school']    = 'JMU'
_df_school['school'] = SCHOOL

_df_combined = pd.concat([_df_jmu, _df_school], ignore_index=True)

_df_combined['interval'] = _df_combined['date'].dt.to_period(TREND_INTERVAL).dt.to_timestamp()

# ── Normalize per 1,000 — drop intervals with too few posts ──────────────
# A month with 1 total post and 1 covid hit = 1,000 per 1,000: not meaningful.
_period_totals = (_df_combined.groupby(['interval', 'school'])
                               .size()
                               .reset_index(name='_total'))
_period_totals = _period_totals[_period_totals['_total'] >= MIN_PERIOD_POSTS]

_rows = []
for kw in TREND_KEYWORDS:
    _mask = _df_combined['text'].str.contains(kw, case=False, na=False)
    _hits = (_df_combined[_mask]
             .groupby(['interval', 'school'])
             .size()
             .reset_index(name='_hits'))
    _m = _hits.merge(_period_totals, on=['interval', 'school'])
    _m['per_1000'] = _m['_hits'] / _m['_total'] * 1000
    _m['keyword'] = kw
    _rows.append(_m[['interval', 'school', 'keyword', 'per_1000']])

_trend_df = pd.concat(_rows, ignore_index=True)

# ── Plot — color = school, line pattern = keyword ─────────────────────────
fig = px.line(
    _trend_df,
    x='interval',
    y='per_1000',
    color='school',
    line_dash='keyword',
    color_discrete_map={'JMU': JMU_COLOR, SCHOOL: SCHOOL_COLOR},
    title=f'Keyword Trends Over Time: JMU vs {SCHOOL}',
    labels={'interval': 'Time Period', 'per_1000': 'Mentions per 1,000 Posts/Comments',
            'school': 'School', 'keyword': 'Keyword'},
    markers=True,
)
fig.update_layout(
    xaxis_title='Time Period',
    yaxis_title='Mentions per 1,000 Posts/Comments',
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="3f12b2e8-2ccd-45f1-92a6-2d772dec99a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3f12b2e8-2ccd-45f1-92a6-2d772dec99a3")) {                    Plotly.newPlot(                        "3f12b2e8-2ccd-45f1-92a6-2d772dec99a3",                        [{"hovertemplate":"School=JMU\u003cbr\u003eKeyword=covid\u003cbr\u003eTime Period=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JMU, covid","line":{"color":"#450084","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"JMU, covid","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00.000000000","2021-01-01T00:00:00.000000000","2022-01-01T00:00:00.000000000","2023-01-01T00:00:00.000000000","2024-01-01T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"QfH924lsQ0C\u002fPbDRuyJLQCyPU8Ox8jhAYYXOYIXOEECLhvjj1uUlQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"School=JMU\u003cbr\u003eKeyword=football\u003cbr\u003eTime Period=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JMU, football","line":{"color":"#450084","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"JMU, football","orientation":"v","showlegend":true,"x":["2015-01-01T00:00:00.000000000","2017-01-01T00:00:00.000000000","2018-01-01T00:00:00.000000000","2019-01-01T00:00:00.000000000","2020-01-01T00:00:00.000000000","2021-01-01T00:00:00.000000000","2023-01-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2026-01-01T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"GutDY31oREC3bdu2bdsxQLITO7ETOyNAdl3XdV3XI0BnAipfARgkQDiM1dbfHhhAYYXOYIXOEECLhvjj1uUlQG9fWb1LHkRAkiRJkiTJOkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"School=JMU\u003cbr\u003eKeyword=tuition\u003cbr\u003eTime Period=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JMU, tuition","line":{"color":"#450084","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"JMU, tuition","orientation":"v","showlegend":true,"x":["2019-01-01T00:00:00.000000000","2020-01-01T00:00:00.000000000","2021-01-01T00:00:00.000000000","2022-01-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2025-01-01T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"7\u002fu+7\u002fu+\u002fz8p0DqFmyEsQNGy4zmVFCBAHQqN18uhAEBjs6DaczINQMAZ1yJBTSVA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"School=UNC\u003cbr\u003eKeyword=covid\u003cbr\u003eTime Period=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UNC, covid","line":{"color":"#4B9CD3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"UNC, covid","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00.000000000","2021-01-01T00:00:00.000000000","2022-01-01T00:00:00.000000000","2023-01-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2025-01-01T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"VI3Mrp4AR0DZyPAnNw9EQNE3LcAwjyBAHp2KrENZHED2b2GJm+kiQBRFURRFUQRA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"School=UNC\u003cbr\u003eKeyword=football\u003cbr\u003eTime Period=%{x}\u003cbr\u003eMentions per 1,000 Posts\u002fComments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UNC, football","line":{"color":"#4B9CD3","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"UNC, football","orientation":"v","showlegend":true,"x":["2019-01-01T00:00:00.000000000","2020-01-01T00:00:00.000 ...

# %% [markdown]
# [ENTER KEYWORD TRENDS ANALYSIS HERE]

# %% [markdown]
# ## Spatial Data Cleaning

# %% [markdown]
# ### JMU

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Give a brief description of the process of cleaning locations for JMU. You may refer back to your experience in previous lessons.
# **Length:** 5-8 Sentences
# **Description:** You want to demonstrate that you read through the data by providing details on where the geoparser made important mistakes and explain why it made those errant inferences. For example, in the demonstration data the geoparser confused JMU with Jiamusi Songjiang International Airport in China because it has the airport code JMU. This is a big mistake because the data is about JMU the university not the airport.
# Finally, were there any cases where you had a hard time determining whether something should be a location or not. For example, there were a number of references to NJ (New Jersey) drivers in the JMU data, did you list New Jersey as a location or did you remove these because they were references to people from New Jersey?

# %% [markdown]
# [ENTER DATA CLEANING - JMU TEXT HERE]

# %% [markdown]
# 📋 **Instructions:**
# The cell below creates two maps: JMU - Data *Before* and JMU Data *After*. Modify the styling parameters to maximize the difference between the two maps. If you have not completed the cleaned JMU map from Lesson 4 this will fallback to a backup. You will not receive credit for the backup file.

# %%
# ── Parameters you can change ─────────────────────────────────────────────
MAP_STYLE  = 'carto-positron'    # ← try 'carto-darkmatter', 'open-street-map'
COLOR      = '#4c78a8'           # ← try any hex color or CSS name, e.g. 'steelblue'
CENTER_LAT = 38.44               # ← map center latitude
CENTER_LON = -78.87              # ← map center longitude
ZOOM       = 6                   # ← zoom level
SIZE_MAX   = 18                  # ← maximum bubble size

# ── Load data ──────────────────────────────────────────────────────────────
_before_raw  = pd.read_csv('../data/JMU/JMU_geoparsed_long.csv')
_after_path  = '../data/JMU/JMU_geoparsed_long_cleaned.csv'
_backup_path = '../data/JMU/JMU_geoparsed_long_cleaned_backup.csv'

if os.path.exists(_after_path):
    _after_raw, _after_label = pd.read_csv(_after_path), 'After cleaning'
else:
    _after_raw   = pd.read_csv(_backup_path)
    _after_label = 'After cleaning (⚠️ backup — complete Part 3 to replace this)'
    print('⚠️  JMU_geoparsed_long_cleaned.csv not found — using backup.')

df_before = aggregate_places(_before_raw)
df_after  = aggregate_places(_after_raw)
print(f'Before: {len(df_before):,} unique places  |  '
      f'After: {len(df_after):,}  |  Removed: {len(df_before) - len(df_after):,}')

# ── Shared map options ─────────────────────────────────────────────────────
_base = dict(
    lat='latitude', lon='longitude',
    size='size_class',
    hover_name='place',
    hover_data={'location_count': True, 'place_type': True,
                'size_class': False, 'latitude': False, 'longitude': False},
    color_discrete_sequence=[COLOR],
    size_max=SIZE_MAX, map_style=MAP_STYLE,
    center={'lat': CENTER_LAT, 'lon': CENTER_LON},
    zoom=ZOOM, height=460,
)

# ── Before map ─────────────────────────────────────────────────────────────
jenks_size_classify(df_before, 4)
px.scatter_map(
    df_before,
    title='JMU — Before cleaning',  # ← change this title
    **_base,
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()

# ── After map ──────────────────────────────────────────────────────────────
jenks_size_classify(df_after, 4)
px.scatter_map(
    df_after,
    title=f'JMU — {_after_label}',  # ← change this title
    **_base,
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# ⚠️  JMU_geoparsed_long_cleaned.csv not found — using backup.
# Before: 322 unique places  |  After: 307  |  Removed: 15
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="032bb121-7e5c-49b8-831c-dd8419db8f40" class="plotly-graph-div" style="height:460px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("032bb121-7e5c-49b8-831c-dd8419db8f40")) {                    Plotly.newPlot(                        "032bb121-7e5c-49b8-831c-dd8419db8f40",                        [{"customdata":[[13,"State",2.0,44.00013,-120.50139],[4,"City",1.0,44.05207,-123.08675],[1,"Country",1.0,43.73141,7.41903],[5,"Building",2.0,44.05827,-123.06849],[4,"State",1.0,40.00032,-86.25027],[1,"City",1.0,47.60621,-122.33207],[6,"State",2.0,47.50012,-120.50147],[87,"State",4.0,38.44957,-78.86892],[11,"State",2.0,38.91706,-77.00025],[77,"State",4.0,37.54812,-77.44675],[3,"City",1.0,32.73569,-97.10807],[2,"City",1
42762,-78.88225],[3,"Building",1.0,38.43361,-78.87278],[3,"City",1.0,51.1851,-0.163],[3,"Country",1.0,31.5,34.75],[3,"State",1.0,31.25044,-99.25061],[3,"State",1.0,44.00034,-72.74983],[3,"State",1.0,32.75041,-86.75026],[4,"Building",1.0,38.43741008,-78.87569563],[2,"Road",1.0,22.31602,113.93663],[2,"State",1.0,38.16452,-79.13383],[2,"State",1.0,65.0,-15.0],[2,"City",1.0,39.29038,-76.61219],[2,"Unknown",1.0,45.83222,-106.60669],[2,"Building",1.0,38.43944,-78.87222],[2,"Building",1.0,38.43861,-78.87167],[2,"City",1.0,38.34982,-81.63262],[2,"City",1.0,36.81904,-76.27494],[2,"City",1.0,42.02561,-123.14391],[2,"State",1.0,39.00039,-75.49992],[2,"Region",1.0,37.02332,-77.36954],[2,"Building",1.0,-35.30653,149.11623],[2,"Country",1.0,48.69096,9.14062],[2,"City",1.0,40.029,-75.62077],[2,"Building",1.0,38.43667,-78.86778],[2,"City",1.0,55.9033,-2.74592],[2,"Unknown",1.0,36.32571,-76.95274],[2,"State",1.0,32.54813,-94.37149],[2,"City",1.0,29.76328,-95.36327],[2,"Unknown",1.0,40.6462,-76.42468],[2,"City",1.0,35.61452,-88.81395],[2,"Building",1.0,37.02194,-76.33333],[2,"Building",1.0,38.43333,-78.85972],[2,"City",1.0,39.11566,-77.5636],[2,"Natural Feature",1.0,34.43027,-119.29317],[2,"City",1.0,39.89937,-82.8122 ...

# %% [markdown]
# ### YOUR SCHOOL <- Change this

# %% [markdown]
# 📋 **Instructions:**
#
# **Task:** Give a brief description of the process of cleaning locations for your school. This mirrors the description you already gave for JMU.
# **Length:** 5-8 Sentences
# **Description:** You want to demonstrate that you read through the data by providing details on where the geoparser made important mistakes and explain why it made those errant inferences. You also want to discuss edge cases where you had a hard time determining whether something was a location or not. Finally, consider hyperlocal places. What were some locations that students spoke about that required some research to figure out. For example, most people outside of JMU don't know what D-Hall is. What is the equivalent of that for your school?

# %% [markdown]
# [ENTER DATA CLEANING - YOUR SCHOOL TEXT HERE]

# %% [markdown]
# 📋 **Instructions:**
# The cell below sets your school variable and verifies that the required data file exists. Make sure you change `UNC` to your school, otherwise the visualizations will not work.
#
# > 👉 **Note:** *Before running this cell, make sure you have completed [project_part_1_data_pipeline.ipynb](project_part_1_data_pipeline.ipynb) for your school. That notebook cleans your data and runs sentiment analysis — without it, the data file this cell checks for will not exist.

# %%
import os

SCHOOL = 'UNC'  # ← change to your school: GMU, ODU, UNC, UVA, VCU, VirginiaTech, WM

_sentiment_path = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned_sentiment.csv'

if not os.path.exists(_sentiment_path):
    print(f'⛔ File not found: {_sentiment_path}')
    print('   Run project_part_1_data_pipeline.ipynb first, then re-run this cell.')
else:
    print(f'✅ {SCHOOL} data found — ready to map.')
# Out:
# ✅ UNC data found — ready to map.

# %% [markdown]
# 📋 **Instructions:**
# The cell below creates two maps: Your school data *Before* and Your school data *After*. Modify the styling parameters to maximize the difference between the two maps.

# %%
# ── Parameters you can change ─────────────────────────────────────────────
MAP_STYLE  = 'carto-positron'    # ← try 'carto-darkmatter', 'open-street-map'
COLOR      = '#4c78a8'           # ← try any hex color or CSS name, e.g. 'steelblue'
CENTER_LAT = 38.44               # ← map center latitude
CENTER_LON = -78.87              # ← map center longitude
ZOOM       = 4                   # ← zoom level
SIZE_MAX   = 18                  # ← maximum bubble size

# ── Load data ──────────────────────────────────────────────────────────────
_before_raw  = pd.read_csv(f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long.csv')
_after_path  = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned.csv'
_backup_path = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned_backup.csv'

if os.path.exists(_after_path):
    _after_raw, _after_label = pd.read_csv(_after_path), 'After cleaning'
elif os.path.exists(_backup_path):
    _after_raw   = pd.read_csv(_backup_path)
    _after_label = 'After cleaning (⚠️ backup — complete Part 3 to replace this)'
    print(f'⚠️  {SCHOOL}_geoparsed_long_cleaned.csv not found — using backup.')
else:
    raise FileNotFoundError(
        f'No cleaned data found for {SCHOOL}. Run project_part_1_data_pipeline.ipynb first.'
    )

df_before = aggregate_places(_before_raw)
df_after  = aggregate_places(_after_raw)
print(f'Before: {len(df_before):,} unique places  |  '
      f'After: {len(df_after):,}  |  Removed: {len(df_before) - len(df_after):,}')

# ── Shared map options ─────────────────────────────────────────────────────
_base = dict(
    lat='latitude', lon='longitude',
    size='size_class',
    hover_name='place',
    hover_data={'location_count': True, 'place_type': True,
                'size_class': False, 'latitude': False, 'longitude': False},
    color_discrete_sequence=[COLOR],
    size_max=SIZE_MAX, map_style=MAP_STYLE,
    center={'lat': CENTER_LAT, 'lon': CENTER_LON},
    zoom=ZOOM, height=460,
)

# ── Before map ─────────────────────────────────────────────────────────────
jenks_size_classify(df_before, 4)
px.scatter_map(
    df_before,
    title=f'{SCHOOL} — Before cleaning',  # ← change this title
    **_base,
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()

# ── After map ──────────────────────────────────────────────────────────────
jenks_size_classify(df_after, 4)
px.scatter_map(
    df_after,
    title=f'{SCHOOL} — {_after_label}',  # ← change this title
    **_base,
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# Before: 370 unique places  |  After: 369  |  Removed: 1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="f7dc14c0-f93b-447e-be1c-82c45433cd8a" class="plotly-graph-div" style="height:460px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f7dc14c0-f93b-447e-be1c-82c45433cd8a")) {                    Plotly.newPlot(                        "f7dc14c0-f93b-447e-be1c-82c45433cd8a",                        [{"customdata":[[132,"State",4.0,35.50069,-80.00032],[95,"Country",4.0,39.76,-98.5],[54,"Building",3.0,36.73954,-82.75461],[55,"City",3.0,34.57461,-79.4381],[42,"Country",3.0,31.5,34.75],[41,"City",3.0,39.96118,-82.99879],[26,"Road",2.0,14.62864,121.11388],[80,"City",4.0,35.94288,-82.70875],[16,"City",2.0,31.50161,34.46672],[21,"City",2.0,35.99403,-78.89862],[12,"City",2.0,35.91014,-79.07529],[11,"City",2.0,34.98333,139.86667],[11,"State",2.0,37.25022,-119.75126],[9,"City",2.0,37.77817,-81.18816],[9,"Country",2.0,56.0,10.0],[8,"Country",2.0,54.75844,-2.69531],[8,"City",2.0,40.44062,-79.99589],[8,"Country",2.0,35.0,105.0],[8,"Building",2.0,33.87703,-104.17413],[8,"City",2.0,35.22709,-80.84313],[11,
9,"State",2.0,30.12131,-93.8939],[3,"Building",1.0,35.91469,-79.04991],[5,"City",2.0,39.16498,-107.48617],[3,"Building",1.0,35.91301,-79.0518],[3,"Country",1.0,6.0,12.5],[3,"Country",1.0,42.83333,12.83333],[3,"State",1.0,44.25029,-85.50033],[3,"State",1.0,40.00032,-89.25037],[3,"City",1.0,41.85003,-87.65005],[2,"Building",1.0,35.9101,-79.0553],[2,"Country",1.0,36.5,127.75],[2,"Unknown",1.0,-16.59836,-143.72349],[2,"City",1.0,31.13019,104.38198],[2,"State",1.0,2.25,102.25],[2,"State",1.0,37.54812,-77.44675],[2,"City",1.0,34.58216,135.46653],[2,"City",1.0,36.67621,-82.38598],[2,"Building",1.0,8.03333,-77.0833],[2,"City",1.0,39.73915,-104.9847],[2,"Building",1.0,40.73889,-74.00889],[2,"City",1.0,39.89674,-79.9745],[2,"Unknown",1.0,32.28096,-103.18602],[2,"City",1.0,51.50853,-0.12574],[2,"Country",1.0,33.0,66.0],[2,"Building",1.0,35.9115,-79.07112],[2,"City",1.0,31.75872,-106.48693],[2,"City",1.0,35.52622,-82.60679],[2,"Building",1.0,35.9043,-79.0429],[2,"City",1.0,41.60899,-72.14591],[2,"Building",1.0,35.91469,-79.05154],[2,"City",1.0,37.87159,-122.27275],[2,"State",1.0,38.25031,-92.50046],[2,"State",1.0,35.75035,-86 ...

# %% [markdown]
# ## Sentiment Overview

# %% [markdown]
# ### JMU

# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Create an "overview" map of sentiment for JMU that highlights the kinds of places people talk about and the strongest emotions.
# **Length**: 4-5 sentences
# **Description**: Before going into comparative analysis with your school, you want to create an overview of both schools. You should create a map that provides the "best" overview. This can be local, regional, national, or global. It all depends on what scale the data ceases to be very useful. You may find that some schools have a far more global perspective while others are more regional. You want to provide as much of a general glance in the map without adding extraneous data. Your description is meant to guide your viewer to salient points.
#
# As a practical matter, you are going to create your map first by jumping to the code cell below and then do your write up. Since this will be an essay, it makes more sense to have the description precede the map that is why you are doing things out of order.

# %% [markdown]
# [ENTER OVERVIEW JMU HERE]

# %%
# ── Your design decisions — change each value and re-run ─────────────────────
MIN_COUNT       =  2     # ← Decision 1: minimum post count
PLACE_TYPES     =  None  # ← Decision 2: list of place types (e.g. ['City', 'Building']), or None for all
N_SIZE_CLASSES  =  5     # ← Decision 3: number of Jenks size classes
N_COLOR_BUCKETS =  5     # ← Decision 4: number of Jenks color buckets
COLOR_SCALE     =  'RdYlGn'          # ← Decision 5: Plotly color scale name (e.g. 'RdYlGn')
MAP_STYLE       =  'carto-positron'  # ← Decision 6: base map style (e.g. 'carto-positron')
CENTER          =  {"lat": 37, "lon": -78}  # ← Decision 7: map center
ZOOM            =  5     # ← Decision 8: zoom level
SIZE_MAX        =  18    # ← Decision 9: maximum bubble size

# ── Load JMU sentiment data ────────────────────────────────────────────────
_jmu_primary = '../data/JMU/JMU_geoparsed_long_cleaned_sentiment.csv'
_jmu_backup  = '../data/JMU/JMU_geoparsed_long_backup_sentiment.csv'

if os.path.exists(_jmu_primary):
    _df_jmu_raw = pd.read_csv(_jmu_primary)
elif os.path.exists(_jmu_backup):
    _df_jmu_raw = pd.read_csv(_jmu_backup)
    print('⚠️  Using JMU backup sentiment — complete the data pipeline to replace this.')
else:
    raise FileNotFoundError('No JMU sentiment data found. Run generate_jmu_backup_sentiment.ipynb.')

# ── Prepare and plot ───────────────────────────────────────────────────────
df_work = filter_places(aggregate_places(_df_jmu_raw, sentiment=True), MIN_COUNT, PLACE_TYPES)
_labels, _cmap = jenks_sentiment_classify(df_work, COLOR_SCALE, N_SIZE_CLASSES, N_COLOR_BUCKETS)
px.scatter_map(
    df_work,
    lat='latitude', lon='longitude',
    size='size_class', color='color_class',
    hover_name='place',
    hover_data={'avg_roberta_compound': ':.3f', 'location_count': True,
                'size_class': False, 'color_class': False,
                'latitude': False, 'longitude': False},
    color_discrete_map=_cmap, category_orders={'color_class': _labels},
    size_max=SIZE_MAX, map_style=MAP_STYLE, center=CENTER, zoom=ZOOM, height=650,
    title='JMU — Sentiment Map',  # ← change this title
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# ⚠️  Using JMU backup sentiment — complete the data pipeline to replace this.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="e4da68c0-2a83-4087-a860-45c17b30256e" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e4da68c0-2a83-4087-a860-45c17b30256e")) {                    Plotly.newPlot(                        "e4da68c0-2a83-4087-a860-45c17b30256e",                        [{"customdata":[[-0.4370314781333333,3,1.0,"-0.77 to -0.44",44.00034,-72.74983],[-0.5072946150000001,2,1.0,"-0.77 to -0.44",38.16452,-79.13383],[-0.765105775,2,1.0,"-0.77 to -0.44",-35.30653,149.11623],[-0.623104985,2,1.0,"-0.77 to -0.44",40.6462,-76.42468],[-0.6391051,2,1.0,"-0.77 to -0.44",33.20984,-87.56917],[-0.692030585,2,1.0,"-0.77 to -0.44",55.25,24.75]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eavg_roberta_compound=%{customdata[0]:.3f}\u003cbr\u003elocation_count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Vermont","Augusta County","Embassy of the United States","I-81 Scenic View","Tuscaloosa","Ukmerg\u0117"],"lat":{"dtype":"f8","bdata":"uXAgJAsARkDbxMn9DhVDQBefAmA8p0HAbVZ9rrZSREBCsoAJ3JpAQAAAAAAAoEtA"},"legendgroup":"-0.77 to -0.44","lon":{"dtype":"f8","bdata":"0uP3Nv0vUsBRTrSrkMhTwA0a+ie4o2JA+tAF9S0bU8BR9wFIbeRVwAAAAAAAwDhA"},"marker":{"color":"rgb(165, 0, 38)","size":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002f"},"sizemode":"area","sizeref":0.015432098765432098},"mode":"markers","name":"-0.77 to -0.44","showlegend":true,"subplot":"map","type":"scattermap"},{"customdata":[[-0.2717795353,52,3.0,"-0.44 to -0.13",39.76,-98.5],[-0.12907372214347826,23,2.0,"-0.44 to -0.13",38.4352348,-78.86911106],[-0.3633739749807143,14,2.0,"-0.44 to -0.13",38.41687425,-78.87158834],[-0.1319483666825,8,1.0,"-0.44 to -0.13",38.47378213,-78.87932529],[-0.2933851212307692,13,2.0,"-0.44 to -0.13",40.16706,-74.49987],[-0.275582477825,8,1.0,"-0.44 to -0.13",38.43399862,-78.87297345],[-0.1514703252568421,19,2.0,"-0.44 to -0.13",38.43764382,-78.87195865],[-0.18461597852857142,7,1.0,"-0.44 to -0.13",38.43193384,-78.86437656],[-0.27243060249999995,4,1.0,"-0.44 to -0.13",46.72903970688112,-117.14614844362796],[-0.173889752,5,1.0,"-0.44 to -0.13",35.50069,-80.00032],[-0.1627617884,5,1.0,"-0.44 to -0.13",33.241787362413646,-97.05608406232872],[-0.1368426896,5,1.0,"-0.44 to -0.13",38.42509027029688,-78.88511990722543],[-0.18401980528333337,6,1.0,"-0.44 to -0.13",38.41849803,-78.84386124],[-0.2588156524,4,1.0,"-0.44 to -0.13",38.430535173016295,-78.86536639338074],[-0.20962304375,4,1.0,"-0.44 to -0.13",43.00035,-75.4999],[-0.14984323475000003,4,1.0,"-0.44 to -0.13",38.978971184839295,-77.35229174876422],[-0.23926587866666668,3,1.0,"-0.44 to -0.13",38.41577634079321,-78.84795694336302],[-0.20377770679999999,3,1.0,"-0.44 to -0.13",25.0,45.0],[-0.25254065333333336,3,1.0,"-0.44 to -0.13",31.5,34.75],[-0.23973499223333336,3,1.0,"-0.44 to -0.13",31.25044,-99.25061],[-0.336629525,2,1.0,"-0.44 to -0.13",22.31602,113.93663],[-0.27539694000000003,2,1.0,"-0.44 to -0.13",39.29038,-76.61219],[-0.13693550999999998,2,1.0,"-0.44 to -0.13",45.83222,-106.60669],[-0.30716545,2,1.0,"-0.44 to -0.13",42.02561,-123.14391],[-0.31047007,2,1.0,"-0.44 to -0.13",39.00039,-75.49992],[-0.14716774,2,1.0,"-0.44 to -0.13",38.43667,-78.86778],[-0.13927560300000003,2,1.0,"-0.44 to -0.13",34.05223,-118.24368],[-0.32641451,2,1.0,"-0.44 to -0.13",43.07305,-89.40123],[-0.24814916799999998,2,1.0,"-0.44 to -0.13",29.77303,-95.58442],[-0.13693550999999998,2,1.0,"-0.44 to -0.13",43.18496,-108.26621],[-0.141158616,2,1.0,"-0.44 to -0.13",38.50096,-76.5294],[-0.32656911,2,1.0,"-0.44 to -0.13",38.98345,-76.48663],[-0.38749875,2,1.0,"-0.44 to -0.13",48.05562,- ...

# %% [markdown]
# #### Significant Locations

# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Write an overview of *three* significant locations in the corpus based on your cleaning and analysis
# **Length**: 4-5 sentences
# **Description**: The description that precedes the map should provide readers with a general guide for what they are looking at. Your description after they see the map should provide an overview of three significant locations in the corpus that might be unknown to someone unfamiliar with the school. For example, on the JMU map D-Hall comes out at a significant place. You want to mention what this place is, where it is, and why it elicits so much conversation. It will help steer them towards the narrative you are constructing.

# %% [markdown]
# [ENTER YOUR ANALYSIS OF THREE SIGNIFICANT LOCATIONS HERE]

# %% [markdown]
# ### YOUR SCHOOL <- Change this

# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Create an "overview" map of sentiment for your school that highlights the kinds of places people talk about and the strongest emotions.
# **Length**: 4-5 sentences
# **Description**: Before going into comparative analysis with your school, you want to create an overview of both schools. You should create a map that provides the "best" overview. This can be local, regional, national, or global. It all depends on what scale the data ceases to be very useful. You may find that some schools have a far more global perspective while others are more regional. You want to provide as much of a general glance in the map without adding extraneous data. Your description is meant to guide your viewer to salient points.
#
# As a practical matter, you are going to create your map first by jumping to the code cell below and then do your write up. Since this will be an essay, it makes more sense to have the description precede the map that is why you are doing things out of order.

# %% [markdown]
# [ENTER OVERVIEW YOUR SCHOOL HERE]

# %%
# ── Your design decisions — change each value and re-run ─────────────────────
MIN_COUNT       =  2     # ← Decision 1: minimum post count
PLACE_TYPES     =  None  # ← Decision 2: list of place types (e.g. ['City', 'Building']), or None for all
N_SIZE_CLASSES  =  5     # ← Decision 3: number of Jenks size classes
N_COLOR_BUCKETS =  5     # ← Decision 4: number of Jenks color buckets
COLOR_SCALE     =  'RdYlGn'          # ← Decision 5: Plotly color scale name (e.g. 'RdYlGn')
MAP_STYLE       =  'carto-positron'  # ← Decision 6: base map style (e.g. 'carto-positron')
CENTER          =  {"lat": 37, "lon": -78}  # ← Decision 7: map center
ZOOM            =  5     # ← Decision 8: zoom level
SIZE_MAX        =  18    # ← Decision 9: maximum bubble size

# ── Load school sentiment data ─────────────────────────────────────────────
_primary = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned_sentiment.csv'
_backup  = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_backup_sentiment.csv'

if os.path.exists(_primary):
    _df_school_raw = pd.read_csv(_primary)
elif os.path.exists(_backup):
    _df_school_raw = pd.read_csv(_backup)
    print(f'⚠️  Using {SCHOOL} backup sentiment — complete the data pipeline to replace this.')
else:
    raise FileNotFoundError(f'No sentiment data found for {SCHOOL}. Run project_part_1_data_pipeline.ipynb first.')

# ── Prepare and plot ───────────────────────────────────────────────────────
df_work = filter_places(aggregate_places(_df_school_raw, sentiment=True), MIN_COUNT, PLACE_TYPES)
_labels, _cmap = jenks_sentiment_classify(df_work, COLOR_SCALE, N_SIZE_CLASSES, N_COLOR_BUCKETS)
px.scatter_map(
    df_work,
    lat='latitude', lon='longitude',
    size='size_class', color='color_class',
    hover_name='place',
    hover_data={'avg_roberta_compound': ':.3f', 'location_count': True,
                'size_class': False, 'color_class': False,
                'latitude': False, 'longitude': False},
    color_discrete_map=_cmap, category_orders={'color_class': _labels},
    size_max=SIZE_MAX, map_style=MAP_STYLE, center=CENTER, zoom=ZOOM, height=650,
    title=f'{SCHOOL} — Sentiment Map',  # ← change this title
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="9694c7c5-c8f9-422b-9d4f-d8a2c9813068" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9694c7c5-c8f9-422b-9d4f-d8a2c9813068")) {                    Plotly.newPlot(                        "9694c7c5-c8f9-422b-9d4f-d8a2c9813068",                        [{"customdata":[[-0.4585491108214286,42,3.0,"-0.75 to -0.41",31.5,34.75],[-0.44269486742857145,7,2.0,"-0.75 to -0.41",35.27766,-102.35403],[-0.6170155455714286,7,2.0,"-0.75 to -0.41",31.92157,35.20329],[-0.46358516971428576,7,2.0,"-0.75 to -0.41",72.0,-40.0],[-0.45521056666666665,3,1.0,"-0.75 to -0.41",23.0,-102.0],[-0.44767606833333334,3,1.0,"-0.75 to -0.41",25.2643,55.29326],[-0.54322759,2,1.0,"-0.75 to -0.41",36.5,127.75],[-0.41005009,2,1.0,"-0.75 to -0.41",39.73915,-104.9847],[-0.49748406,2,1.0,"-0.75 to -0.41",51.5,10.5],[-0.430839965,2,1.0,"-0.75 to -0.41",35
# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Write an overview of *three* significant locations in the corpus based on your cleaning and analysis
# **Length**: 4-5 sentences
# **Description**: The description that precedes the map should provide readers with a general guide for what they are looking at. Your description after they see the map should provide an overview of three significant locations in the corpus that might be unknown to someone unfamiliar with the school. For example, on the JMU map D-Hall comes out at a significant place. You want to mention what this place is, where it is, and why it elicits so much conversation. It will help steer them towards the narrative you are constructing.

# %% [markdown]
# [WRITE YOUR OVERVIEW OF THREE SIGNIFICANT LOCATIONS HERE]

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### JMU

# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Write an analysis of the sentiment map of JMU that tries to answer your hypothesis.
# **Length**: 4-5 sentences
# **Description**: After giving your overview and your highlight of three locations, you are going to analyze the sentiment map in terms of your hypothesis. The key is to make sure that the map and your analysis match. Rather than trying to tell a "global" story, you want to tell a detailed story about one specific issue. You want the map to show the minimum number of locations to tell this story. This story will be the evidence for or against your hypothesis. If the evidence contradicts your hypothesis that is a sign of good scholarship, don't be afraid to contradict your earlier assessment.

# %% [markdown]
# [ENTER JMU SENTIMENT ANALYSIS HERE]

# %%
# ── Your design decisions — change each value and re-run ─────────────────────
MIN_COUNT        =  2          # ← Decision 1: minimum post count
PLACE_TYPES      =  None       # ← Decision 2: list of place types, or None for all
N_SIZE_CLASSES   =  5          # ← Decision 3: number of Jenks size buckets (count)
N_COLOR_BUCKETS  =  5          # ← Decision 4: number of Jenks color buckets (sentiment)
COLOR_SCALE      =  'RdYlGn'   # ← Decision 5: color scale shared by both maps
MAP_STYLE        =  'carto-positron'        # ← Decision 6: base map style
CENTER           =  {"lat": 37, "lon": -78} # ← Decision 7: map center
ZOOM             =  5          # ← Decision 8: zoom level
SIZE_MAX         =  18         # ← Decision 9: maximum bubble size

# ── Load JMU sentiment data ────────────────────────────────────────────────
_jmu_primary = '../data/JMU/JMU_geoparsed_long_cleaned_sentiment.csv'
_jmu_backup  = '../data/JMU/JMU_geoparsed_long_backup_sentiment.csv'

if os.path.exists(_jmu_primary):
    _df_jmu_raw = pd.read_csv(_jmu_primary)
elif os.path.exists(_jmu_backup):
    _df_jmu_raw = pd.read_csv(_jmu_backup)
    print('⚠️  Using JMU backup sentiment — complete the data pipeline to replace this.')
else:
    raise FileNotFoundError('No JMU sentiment data found. Run generate_jmu_backup_sentiment.ipynb.')

# ── Load school sentiment data ─────────────────────────────────────────────
_primary = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_cleaned_sentiment.csv'
_backup  = f'../data/{SCHOOL}/{SCHOOL}_geoparsed_long_backup_sentiment.csv'

if os.path.exists(_primary):
    _df_school_raw = pd.read_csv(_primary)
elif os.path.exists(_backup):
    _df_school_raw = pd.read_csv(_backup)
    print(f'⚠️  Using {SCHOOL} backup sentiment — complete the data pipeline to replace this.')
else:
    raise FileNotFoundError(f'No sentiment data found for {SCHOOL}. Run project_part_1_data_pipeline.ipynb first.')

# ── Aggregate, combine, classify ──────────────────────────────────────────
# Combining both datasets before classification means every bubble across
# both maps shares the same Jenks bin boundaries for size and color.
_df_jmu    = filter_places(aggregate_places(_df_jmu_raw,    sentiment=True), MIN_COUNT, PLACE_TYPES)
_df_school = filter_places(aggregate_places(_df_school_raw, sentiment=True), MIN_COUNT, PLACE_TYPES)
_n_jmu     = len(_df_jmu)
_df_all    = pd.concat([_df_jmu, _df_school], ignore_index=True)

_labels, _cmap = jenks_sentiment_classify(_df_all, COLOR_SCALE, N_SIZE_CLASSES, N_COLOR_BUCKETS)

# Split back with shared size_class + color_class intact
df_jmu_comp    = _df_all.iloc[:_n_jmu].copy()
df_school_comp = _df_all.iloc[_n_jmu:].copy()
print(f'JMU: {len(df_jmu_comp):,} places  |  {SCHOOL}: {len(df_school_comp):,} places')
print(f'Shared sentiment bins: {_labels}')


# ── JMU map ───────────────────────────────────────────────────────────────
px.scatter_map(
    df_jmu_comp,
    lat='latitude', lon='longitude',
    size='size_class', color='color_class',
    hover_name='place',
    hover_data={'avg_roberta_compound': ':.3f', 'location_count': True,
                'size_class': False, 'color_class': False,
                'latitude': False, 'longitude': False},
    color_discrete_map=_cmap, category_orders={'color_class': _labels},
    size_max=SIZE_MAX, map_style=MAP_STYLE, center=CENTER, zoom=ZOOM, height=650,
    title='JMU — Comparative Sentiment Map',  # ← change this title
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# ⚠️  Using JMU backup sentiment — complete the data pipeline to replace this.
# JMU: 110 places  |  UNC: 132 places
# Shared sentiment bins: ['-0.77 to -0.36', '-0.36 to -0.13', '-0.13 to 0.09', '0.09 to 0.29', '0.29 to 0.97']
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="f5b7c870-ebd4-4fe5-854c-b01734bb9dfc" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f5b7c870-ebd4-4fe5-854c-b01734bb9dfc")) {                    Plotly.newPlot(                        "f5b7c870-ebd4-4fe5-854c-b01734bb9dfc",                        [{"customdata":[[-0.3633739749807143,14,2.0,"-0.77 to -0.36",38.41687425,-78.87158834],[-0.4370314781333333,3,1.0,"-0.77 to -0.36",44.00034,-72.74983],[-0.5072946150000001,2,1.0,"-0.77 to -0.36",38.16452,-79.13383],[-0.765105775,2,1.0,"-0.77 to -0.36",-35.30653,149.11623],[-0.623104985,2,1.0,"-0.77 to -0.36",40.6462,-76.42468],[-0.6391051,2,1.0,"-0.77 to -0.36",33.20984,-87.56917],[-0.692030585,2,1.0,"-0.77 to -0.36",55.25,24.75],[-0.38749875,2,1.0,"-0.77 to -0.36",48.05562,-122.11265]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eavg_roberta_compound=%{customdata[0]:.3f}\u003cbr\u003elocation_count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["The Hills Southview Apartments","Vermont","Augusta County","Embassy of the United States","I-81 Scenic View","Tuscaloosa","Ukmerg\u0117","Walmart"],"lat":{"dtype":"f8","bdata":"syWrIlw1Q0C5cCAkCwBGQNvEyf0OFUNAF58CYDynQcBtVn2utlJEQEKygAncmkBAAAAAAACgS0BzgGCOHgdIQA=="},"legendgroup":"-0.77 to -0.36","lon":{"dtype":"f8","bdata":"\u002f\u002fd1Gsi3U8DS4\u002fc2\u002fS9SwFFOtKuQyFPADRr6J7ijYkD60AX1LRtTwFH3AUht5FXAAAAAAADAOEA+eVioNYdewA=="},"marker":{"color":"rgb(165, 0, 38)","size":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADw
# Run the cell above first — this cell reuses df_school_comp, _cmap, _labels,
# and the map settings (SIZE_MAX, MAP_STYLE, CENTER, ZOOM) already set there.
px.scatter_map(
    df_school_comp,
    lat='latitude', lon='longitude',
    size='size_class', color='color_class',
    hover_name='place',
    hover_data={'avg_roberta_compound': ':.3f', 'location_count': True,
                'size_class': False, 'color_class': False,
                'latitude': False, 'longitude': False},
    color_discrete_map=_cmap, category_orders={'color_class': _labels},
    size_max=SIZE_MAX, map_style=MAP_STYLE, center=CENTER, zoom=ZOOM, height=650,
    title=f'{SCHOOL} — Comparative Sentiment Map',  # ← change this title
).update_layout(margin=dict(r=0, t=50, l=0, b=0)).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="fea429fe-c257-48f8-8d02-c3b244fbceb1" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fea429fe-c257-48f8-8d02-c3b244fbceb1")) {                    Plotly.newPlot(                        "fea429fe-c257-48f8-8d02-c3b244fbceb1",                        [{"customdata":[[-0.4585491108214286,42,3.0,"-0.77 to -0.36",31.5,34.75],[-0.38169669944375,16,2.0,"-0.77 to -0.36",31.50161,34.46672],[-0.368847543,8,2.0,"-0.77 to -0.36",40.44062,-79.99589],[-0.44269486742857145,7,2.0,"-0.77 to -0.36",35.27766,-102.35403],[-0.6170155455714286,7,2.0,"-0.77 to -0.36",31.92157,35.20329],[-0.46358516971428576,7,2.0,"-0.77 to -0.36",72.0,-40.0],[-0.39378084625,4,1.0,"-0.77 to -0.36",-35.30653,149.11623],[-0.3657642526666667,3,1.0,"-0.77 to -0.36",0.0,0.0],[-0.45521056666666665,3,1.0,"-0.77 to -0.36",23.0,-102.0],[-0.44767606833333334,3,1.0,"-0.77 to -0.36",25.2643,55.29326],[-0.3686999606666667,3,1.0,"-0.77 to -0.36",44.25029,-85.50033],[-0.54322759,2,1.0,"-0.77 to -0.36",36.5,127.75],[-0.41005009,2,1.0,"-0.77 to -0.36",39.73915,-104.9847],[-0.49748406,2,1.0,"-0.77 to -0.36",51.5,10.5],[-0.430839965,2,1.0,"-0.77 to -0.36",35.60095,-82.55402],[-0.454805315,2,1.0,"-0.77 to -0.36",35.91075,-79.05048],[-0.6163358099999999,3,1.0,"-0.77 to -0.36",41.37454,-72.10035],[-0.474120457,2,1.0,"-0.77 to -0.36",42.35843,-71.05977],[-0.47242953169999996,2,1.0,"-0.77 to -0.36",47.60621,-122.33207],[-0.39670251,2,1.0,"-0.77 to -0.36",46.42917,-76.18611],[-0.74587765,2,1.0,"-0.77 to -0.36",52.16045,-0.70312],[-0.46919587500000004,2,1.0,"-0.77 to -0.36",48.09361,-108.16402]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eavg_roberta_compound=%{customdata[0]:.3f}\u003cbr\u003elocation_count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["State of Israel","Gaza","Pittsburgh","Territories of the United States","Palestine","Greenland","Embassy of the United States","Earth","Mexico","Al Bank al Br\u012b\u0163\u0101n\u012b lish Sharq al Awsa\u0163","Michigan","Republic of Korea","Denver","Federal Republic of Germany","Asheville","Polk Place","Hamilton Hall","Boston","Seattle","Lac Natty","England","Phillips"],"lat":{"dtype":"f8","bdata":"AAAAAACAP0C4WFGDaYA\u002fQFX7dDxmOERAJLTlXIqjQUCH+fIC7Os\u002fQAAAAAAAAFJAF58CYDynQcAAAAAAAAAAAAAAAAAAADdAMlUwKqlDOUAHQrKACSBGQAAAAAAAQEJAUWuad5zeQ0AAAAAAAMBJQP5D+u3rzEFAf2q8dJP0QUCdhT3t8K9EQODzwwjhLUVAC0EOSpjNR0BQNuUK7zZHQFRSJ6CJFEpADkqYafsLSEA="},"legendgroup":"-0.77 to -0.36","lon":{"dtype":"f8","bdata":"AAAAAABgQUDPMSB7vTtBQHYaaam8\u002f1PAYvNxbaiWWcBLzR5oBZpBQAAAAAAAAETADRr6J7ijYkAAAAAAAAAAAAAAAAAAgFnAy5wui4mlS0BLzR5oBWBVwAAAAAAA8F9AwhcmUwU\u002fWsAAAAAAAAAlQB1VTRB1o1TAiEZ3EDvDU8DVCWgibAZSwAvSjEXTw1HA5X6HokCVXsBZ3eo56QtTwI47pYP1f+a\u002f9Pi9TX8KW8A="},"marker":{"color":"rgb(165, 0, 38)","size":{"dtype":"f8","bdata":"AAAAAAAACEAAAAAAAAAAQAAAAAAAAABAAAAAAAAAAEAAAAAAAAAAQAAAAAAAAABAAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8="},"sizemode":"area","sizeref":0.015432098765432098},"mode":"markers","name":"-0.77 to -0.36","showlegend":true,"subplot":"map","type":"scattermap"},{"customdata":[[-0.26443156382842103,95,4.0,"-0.36 to -0.13",39.76,-98.5],[-0.14712064499850747,67,4.0,"-0.36 to -0.13",35.91208961361997,-79.0584622314049],[-0.24998809863636365,11,2.0,"-0.36 to -0.13",35.90250555489845,-79.04275385216378],[-0.27218289019444447,9,2.0,"-0.36 to -0.13",37.77817,-81.18816],[-0.183612152,8,2.0,"-0.36 to -0.13",35.22709,-80.84313],[-0.28568282,7,2.0,"-0.36 to -0 ...

# %% [markdown]
# ## Conclusion and Further Research

# %% [markdown]
# 📋 **Instructions:**
#
# **Task**: Write a conclusion that ties everything together.
# **Length**: 5-8 sentences (1-2 paragraphs)
# **Description**: Write a conclusion in which you lead with your initial hypothesis and explain whether the data proves, disproves or nuances your hypothesis. For example, you may have found that there is a strong focus on the campus community at JMU, but did not necessarily find that a commuter school had significantly less of a community focus. In this case, you neither proved nor disproved your thesis, but rather nuanced it a bit. You should round out your conclusion by thinking through what type of data you could have collected to help prove your point more. This is your nod towards further research.

# %% [markdown]
# ---
#
# ## Lesson Summary
#
# **Introduction & Hypothesis**
# - Stated your research question and articulated a falsifiable hypothesis about sentiment differences between JMU and your school
#
# **Corpus Description**
# - Described the size, date range, and composition of your Reddit dataset in plain language for a general audience
#
# **Corpus Analysis — Key Moments, Key Topics, Keyword Trends**
# - Used pandas aggregation and Plotly charts to identify the most discussed topics and any notable spikes or drops in posting volume over time
#
# **Spatial Data Cleaning**
# - Reviewed and compared the geographic distribution of posts for both JMU and your school; resolved any obvious geocoding errors before the sentiment pass
#
# **Sentiment Overview & Sentiment Analysis**
# - Interpreted the RoBERTa compound scores for both schools; compared distributions and identified the locations with the strongest positive and negative sentiment signals
#
# **Conclusion and Further Research**
# - Connected your findings back to your original hypothesis and identified what additional data would strengthen the argument
#
# ➡️ **Next:** [Project Part 3 — Interactive Tour](project_part_3_interactive_tour.ipynb)
