# %% [markdown]
# # Lesson 1: The Team Page
#
# ## Overview
#
# In this lesson, we are going to build our team page. Not only does this complete the first phase of the project. It will get you a better understanding of the collaborative workflow.
#
# By the end of this lesson you will have:
# - Built a team page by editing HTML directly
# - Discovered why that approach breaks down
# - Used Python Jupyter to generate the same page automatically from a spreadsheet
# - Understood why separating *data* from *presentation* is a core principle of computing
# - Pushed content to the web and updated the first part of your project
#
# This lesson introduces two ideas that will recur throughout the whole unit:
#
# 1. **Variables** — giving the computer a name for a piece of information so it can reuse it
# 2. **Input / Output (I/O)** — the computer reads something in, does work, writes something out

# %% [markdown]
# ---
#
# ## Part 1 — What is a Website?
#
# Every webpage you visit in a browser is built from a text file called **HTML** (HyperText Markup Language). HTML uses *tags* — words wrapped in angle brackets — to describe what each piece of content is.
#
# ```html
# <h3>Alex Rivera</h3>         ← a heading
# <p>Digital Studies</p>       ← a paragraph
# <a href="...">GitHub</a>    ← a clickable link
# ```
#
# A browser reads those tags and turns them into the page you see. The *content* (names, text, links) and the *instructions* (tags) are mixed together in the same file.
#
# Generally, HTML handles the structure of the page. As you will learn later, CSS controls styling and JavaScript controls the interactivity. These three languages, HTML, CSS, and JS are the foundation of modern web coding.
#
# Open the file `team_static.html` in your file explorer. It should appear in the **Explorer panel** on the left. You can also right-click it and choose **Open with → Browser Preview** (or simply open it in a browser) to see what it looks like before you've filled anything in.

# %% [markdown]
# ---
#
# ## Part 2 — Task A: Fill In Your Team
#
# Open `team_static.html` in Codespaces (click on it in the Explorer panel).
#
# You will see five card blocks in the HTML, each containing comments like:
#
# ```html
# <!-- FULL NAME e.g. Alex Rivera -->
# <!-- MAJOR e.g. Digital Studies -->
# <!-- ROLE e.g. Data Collection -->
# <!-- GITHUB URL -->
# <!-- INITIALS e.g. AR -->
# ```
#
# **Replace the comments for your specific team member number. Do not touch any of the other comments.** Delete the whole comment including the `<!--` and `-->` and type the actual value directly.
#
# For example:
# ```html
# <!-- Before -->
# <h3><!-- FULL NAME e.g. Alex Rivera --></h3>
#
# <!-- After -->
# <h3>Alex Rivera</h3>
# ```
#
# When you're done, save the file (`Ctrl+S`) and refresh your browser preview. You should see your team cards filled in.

# %% [markdown]
# ---
#
# ## Part 2.2: Update your changes
#
# Once you have made your changes, you are going to "push" the new file to the web. ***Remember you should have only change the name card associated with your team member number***
#
# 1. Open Source Control on the left
# 2. Click the + next to changes and commit all
# 3. In the message box enter the following commit message, "Updated about card"
# 4. Click Commit
# 5. Click Sync changes
# 6. You will be asked to "pull" as well. Click "yes, don't remind me"
# 7. Wait till all of your team members have done this
# 8. Now everyone should "pull" all changes by clicking the "synchronize" changes button
# 9. You should see your own static page update
#
# In the beginning, this will feel like a long and tedious procedure. You will get used to it. Remember that this only works if everyone is committed to only changing what they agreed to. If you accidentally change something for a team member you will get a merge error.

# %% [markdown]
# ---
#
# ## Part 3 — Sort Alphabetically
#
# Imagine that for the page, your team wants to be listed alphabetically by last name.
#
# Designate one person in your group to rearrange the card blocks in `team_static.html` so they appear in alphabetical order by last name.
#
# 1. You can do this by highlighting the entire code block from the first comment before the block to the last `</div>` in the block.
#
# ```html
#  <!-- ── TEAM MEMBER 1 (Project Lead)-->
#  ...
#  </div>
#  ```
# 2. You can then cut+paste the blocks in the correct order
#    1. Windows cut= ctrl+x
#    2. Windows paste = ctrl+v
#    3. mac = cmd+x
#    4. mac = cmd+v
# 3. Ctrl+S or CMD +S to save
# 4. ***Do not commit***
#
# **Questions:**
# - Was this frustrating to do?
# - If your group had 30 members, how long would this take?
# - What would you if you suddenly decided to group these by major?
#
# ### Part 3.1 Discard Changes
#
# Because the changes to `team_static.html` will cause a merge error because everyone on the team changed the file. We do not want to stage these changes. You are going to discard them.
# The quickest way to do this is to go to the `source control menu` and click on the `discard changes` icon next to the file. This will return the `team_static.html` to the last committed version.

# %% [markdown]
# ---
#
# ## Part 4 — The Problem with Hardcoding
#
# What you just did is called **hardcoding** — writing specific values directly into a file that is supposed to be *structure*, not *content*.
#
# Here's the core problem:
#
# > When data and presentation are mixed together, every change to the data requires a human to find and edit code.
#
# In a small team this is annoying. At real scale — a company website with thousands of employees, a university directory, a news article database — it becomes impossible.
#
# The solution is **separation of concerns**: keep the data in one place, keep the presentation instructions in another, and write code that connects them.
#
# You already use this pattern every day without thinking about it. A Google Sheets spreadsheet is *data*. The chart Google Sheets draws from it is *presentation*. If you add a row to the spreadsheet, the chart updates automatically. You didn't touch the chart.
#
# That is exactly what we are going to do with your team page.

# %% [markdown]
# ---
#
# ## Part 6 — Data in a Spreadsheet
#
# Open the file `data/team_template.csv` in VS Code or in a spreadsheet application.
#
# A **CSV** (Comma-Separated Values) file is the simplest possible spreadsheet format. Each line is a row. Each comma separates a column. The first row is the column headers.
#
# ```
# first_name,last_name,major,role,github,headshot
# Alex,Rivera,Digital Studies,Data Collection,https://github.com/alexrivera,
# ...
# ```
#
# **Your task:** Copy `data/team_template.csv` and rename the copy to `data/team.csv`. Fill in one row per team member. The template has five rows pre-labelled `member1` through `member5` — replace the placeholder text in each row with your real information, including replacing the role with your actual role (e.g. Data Collection, Visualization, Writing). Don't worry about the order; we'll let the computer sort it.
#
# The `headshot` column is optional — leave it blank if you don't have a photo URL.
#
# > **Note:** Any row where the `role` still says `member1`, `member2`, etc. will be automatically skipped when the team page is generated — only fully filled-in rows will appear on the site.

# %% [markdown]
# ---
#
# ## Part 7 — What is a Variable?
#
# Before we run any code, one concept to understand: a **variable** is just a label the computer uses to remember a value.
#
# ```python
# name = "Alex Rivera"    # the label is 'name'; the value is 'Alex Rivera'
# major = "Digital Studies"
# ```
#
# You've been doing this in HTML too — just without Python syntax. The difference is that in Python, variables can be **computed** from other variables, and they can be **reused** anywhere in the program without retyping.
#
# When we load your `team.csv` into Python, every column header becomes a variable Python can work with. Every row becomes a set of values for those variables. Python can then use those variables to write the JSON file that the team page reads.

# %% [markdown]
# ---
#
# ## Part 8 — Generate the Team Page
#
# The script `generate_team_json.py` does three things:
# 1. **Reads** `data/team.csv` into Python (Input)
# 2. **Sorts** the rows alphabetically by last name
# 3. **Writes** `team_data.json` into the final project folder (Output)
#
# The final project's `team.html` — the real version, not the static version you edited — already knows how to read that JSON file and build the cards automatically using JavaScript. You never need to touch the HTML again.
#
# Run the cell below. If your `data/team.csv` is filled in, you should see a confirmation listing all your team members in alphabetical order.

# %%
# %run generate_team_json.py
# Out:
# ✅ Wrote 1 team members to:
#    c:\Users\joost\My Drive (joostburgers@gmail.com)\Teaching\JMU\Courses\digital_studies_resources\repos\jupyter_hub_codespace\project_5_mapping_emotions\team_data.json
#
#    Joost Burgers — Digital Studies — Coordinator

# %% [markdown]
#     "Now open `project_5_mapping_emotions/team.html` in a browser. Your team cards should appear — in alphabetical order — without you having manually arranged anything in the HTML."

# %% [markdown]
# ---
#
# ## Part 9 — What Just Happened?
#
# Let's look at the key lines inside `generate_team_json.py`. Open it in VS Code while you read this.
#
# ```python
# df = pd.read_csv(INPUT_CSV)          # Input: load the spreadsheet
# df = df.sort_values("_last_name")    # Compute: sort the rows
# json.dump(output, f)                 # Output: write the JSON file
# ```
#
# These three lines — **read, transform, write** — are the fundamental pattern of almost everything we will do in this course:
#
# | Step | Name | What it means |
# |---|---|---|
# | Read | **Ingest** | Get data from somewhere into Python |
# | Transform | **Wrangling / Analysis** | Shape or analyze the data |
# | Write | **Output** | Save a result or build a presentation |
#
# In future lessons, the "data" will be thousands of Reddit posts instead of five names. The "transform" step will involve finding locations and measuring sentiment instead of sorting alphabetically. But the pattern — and Python's role in it — is exactly the same.
#
# ---
#
# ### Discussion Questions
#
# 1. If a team member changes their GitHub username, how do you update the website now, compared to before?
# 2. The script sorts by last name automatically. What would you have to change in `team.csv` to get a different sort order?
# 3. The final project's `team.html` never changes — only `team_data.json` does. Why is this a better design?
# 4. Where else in everyday life do you see "data" separated from "presentation"? (Think: music streaming apps, online stores, social media feeds.)
